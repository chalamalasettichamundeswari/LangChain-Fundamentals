# %%
import os
from dotenv import load_dotenv
load_dotenv()#load all env variables

HUGGING_FACEHUB_API_KEY = os.getenv("HUGGING_FACEHUB_API_KEY")
HUGGING_FACEHUB_API_KEY

os.environ["HUGGING_FACEHUB_API_KEY"] = os.getenv("HUGGING_FACEHUB_API_KEY")

# %% [markdown]
# Sentence Transformers on Hugging Face
#
# models that convert sentences or texts into numerical vectors (embeddings) that capture their meaning. You can use them for tasks like semantic search, clustering, or similarity comparison.

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
text="This is a test document."
query_result = embeddings.embed_query(text)
query_result
# dimension of the embedding
len(query_result) 

doc_result = embeddings.embed_documents([text])
len(doc_result)
# Out:
# 1

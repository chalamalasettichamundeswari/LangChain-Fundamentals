# %% [markdown]
# OLLMA
#
# Ollama supports embedding models, making it possible to build retrieval augmented generation(RAG) applications that combine text prompts with existing documents or other data.
#
# The output of embedDocs and embedQuery should be a list of vectors (arrays of numbers), where each vector represents the embedding of the input text. The length of each vector (e.g., 1024, 2048)
#
# Other Embedded Models
#
# https://ollama.com/blog/embedding-models

# %%
from langchain_community.embeddings import OllamaEmbeddings
embeddings=(
    OllamaEmbeddings(model="gemma:2b")
)
embedDocs = embeddings.embed_documents(["Alpha is the first letter of Greek alphabet ", "Beta is the second letter of Greek alphabet"])
# embedDocs

embedQuery = embeddings.embed_query("What is the first letter of Greek alphabet?")
# embedQuery

print(type(embedQuery)) 
print(len(embedQuery)) 
print(embedQuery[:10])
# Out:
# <class 'list'>
# 2048
# [-3.3637921810150146, 0.36307603120803833, -1.0763585567474365, 0.05141269788146019, -1.044549584388733, 0.15300233662128448, -1.1236240863800049, 0.2387552708387375, 0.30868080258369446, -1.49760901927948]
